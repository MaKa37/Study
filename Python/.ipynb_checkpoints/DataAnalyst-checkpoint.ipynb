# %%
import pandas as pd
import numpy as np

# %%
# Numpy 연산
x = np.array([10, 20, 30])
print(x)
type(x)

y = x / 7
print(y, "\n")

x = np.array([1.0, 2.0, 3.0])
y = np.array([2.0, 4.0, 6.0])

print(x + y)
print(x - y)
print(x * y)
print(x / y)
# Out:
# [10 20 30]
# [1.42857143 2.85714286 4.28571429]
#
# [3. 6. 9.]
# [-1. -2. -3.]
# [ 2.  8. 18.]
# [0.5 0.5 0.5]
